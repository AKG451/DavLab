# %%
"""
1. Generate a 3x4 NumPy array with random integers between 1
and 50.
a. Calculate and print the Mean, Median, and Standard Deviation
of the array
b. Print the Sum of all elements and the sum of each row.
c. Reshape the 3x4 array into a 2x6 array and print it.
"""
import numpy as np
random_array = np.random.randint(1,51,size=(3,4))
mean_val = np.mean(random_array)
median_val = np.median(random_array)
std_val = np.std(random_array)
print(f"Mean:{mean_val}, Median: {median_val}, Standard Deviation: {std_val}")
sum_value = np.sum(random_array)
sum_row = np.sum(random_array, axis=1)
print(f"Sum of Value:{sum_value}, Sum of Row: {sum_row}")
new_array = random_array.reshape(6,2)
print(f"{new_array}")
# Out:
# Mean:29.666666666666668, Median: 33.0, Standard Deviation: 14.067298564006128
# Sum of Value:356, Sum of Row: [117  88 151]
# [[31 43]
#  [31 12]
#  [38 41]
#  [ 6  3]
#  [43 35]
#  [29 44]]

# %%
"""
2. Create two (3 * 3) matrices using NumPy and print it. Perform
and print the results of the following linear algebra operations
a. Matrix addition
b. Matrix subtraction
c. Matrix multiplication (element-wise and dot product)
d. Transpose of a matrix
e. Determinant and inverse (if applicable)
"""

import numpy as np

A = np.random.randint(0, 100, size=(3, 3))
B = np.random.randint(0, 100, size=(3, 3))
addition = np.add(A, B)
sub = np.subtract(A,B)
elementWise = A*B
dotProduct = np.dot(A,B)
transpose = (A.T,B.T)
deterA = np.linalg.det(A)
deterB = np.linalg.det(B)
if(deterA!=0):
    invA = np.linalg.inv(A)
if(deterB!=0):
    invB = np.linalg.inv(B)
print(f"Matrix A:\n{A}\nMatrix B:\n{B}\nAddition:\n{addition}\nSubtraction:\n{sub}\nElement-wise Multiplication:\n{elementWise}\nDot Product:\n{dotProduct}\n")
print(f"Transpose of A:\n{transpose[0]}\nTranspose of B:\n{transpose[1]}\nDeterminant of A: {deterA}\nDeterminant of B: {deterB}")
print(f"Inverse of A:\n{invA}\nInverse of B:\n{invB}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      58     try:
# ---> 59         return bound(*args, **kwds)
#      60     except TypeError:
#
# TypeError: only integer scalar arrays can be converted to a scalar index
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10890/975082563.py in <module>
#      17 elementWise = A*B
#      18 dotProduct = np.dot(A,B)
# ---> 19 transpose = np.transpose(A,B)
#      20 deterA = np.linalg.det(A)
#      21 deterB = np.linalg.det(B)
#
# ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py in transpose(a, axes)
#     653
#     654     """
# --> 655     return _wrapfunc(a, 'transpose', axes)
#     656
# ...
